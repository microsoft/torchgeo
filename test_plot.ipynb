# %%
from torchgeo.datasets import NCCM, BoundingBox
import os

# %%
ds = NCCM(download=True)
# Out:
# /Users/shreyakannan/Desktop/torchgeo/torchgeo/datasets/geo.py:312: UserWarning: Could not find any relevant files for provided path 'data'. Path was ignored.
#   warnings.warn(
# Downloading https://figshare.com/ndownloader/articles/13090442/versions/1 to data/13090442.zip
#  23%|██▎       | 542769152/2385087027 [07:59<27:07, 1132235.52it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds = NCCM(download=True)
#
# File ~/Desktop/torchgeo/torchgeo/datasets/nccm.py:108, in NCCM.__init__(self, paths, crs, res, transforms, cache, download, checksum)
#     105 self.ordinal_map = torch.zeros(max(self.cmap.keys()), dtype=self.dtype)
#     106 self.ordinal_cmap = torch.zeros((5, 4), dtype=torch.uint8)
# --> 108 self._verify()
#     109 super().__init__(paths, crs, res, transforms=transforms, cache=cache)
#     111 for i, (k, v) in enumerate(self.cmap.items()):
#
# File ~/Desktop/torchgeo/torchgeo/datasets/nccm.py:149, in NCCM._verify(self)
#     146     raise DatasetNotFoundError(self)
#     148 # Download the dataset
# --> 149 self._download()
#     150 self._extract()
#
# File ~/Desktop/torchgeo/torchgeo/datasets/nccm.py:155, in NCCM._download(self)
#     153 """Download the dataset."""
#     154 filename = "13090442.zip"
# --> 155 download_url(
#     156     self.url, self.paths, filename, md5=self.md5 if self.checksum else None
#     157 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/utils.py:144, in download_url(url, root, filename, md5, max_redirect_hops)
#     142 try:
#     143     print("Downloading " + url + " to " + fpath)
# --> 144     _urlretrieve(url, fpath)
#     145 except (urllib.error.URLError, OSError) as e:  # type: ignore[attr-defined]
#     146     if url[:5] == "https":
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/utils.py:48, in _urlretrieve(url, filename, chunk_size)
#      46 def _urlretrieve(url: str, filename: str, chunk_size: int = 1024 * 32) -> None:
#      47     with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
# ---> 48         _save_response_content(iter(lambda: response.read(chunk_size), b""), filename, length=response.length)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/utils.py:37, in _save_response_content(content, destination, length)
#      31 def _save_response_content(
#      32     content: Iterator[bytes],
#      33     destination: str,
#      34     length: Optional[int] = None,
#      35 ) -> None:
#      36     with open(destination, "wb") as fh, tqdm(total=length) as pbar:
# ---> 37         for chunk in content:
#      38             # filter out keep-alive new chunks
#      39             if not chunk:
#      40                 continue
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/utils.py:48, in _urlretrieve.<locals>.<lambda>()
#      46 def _urlretrieve(url: str, filename: str, chunk_size: int = 1024 * 32) -> None:
#      47     with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
# ---> 48         _save_response_content(iter(lambda: response.read(chunk_size), b""), filename, length=response.length)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
box = BoundingBox(134.0, 134.4, 47.5, 47.9, 2018, 2018)
sample = ds[box]
figure = ds.plot(sample)

# %%
box = BoundingBox(132.4, 132.8, 46.1, 46.5, 2019, 2019)
sample = ds[box]
figure = ds.plot(sample)

# %%
box = BoundingBox(123.5, 123.9, 47.8, 48.2, 2019, 2019)
sample = ds[box]
figure = ds.plot(sample)
