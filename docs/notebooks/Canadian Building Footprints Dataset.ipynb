# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../..")
import os

import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
from torchgeo.datasets import CanadianBuildingFootprints
from torchgeo.samplers import RandomGeoSampler
from torchgeo.datasets.utils import BoundingBox

# %%
ROOT_DIR = os.path.expanduser("~/ssdprivate/cbf/")

# %% [markdown]
# ## Visualization example

# %%
# %%time
ds = CanadianBuildingFootprints(
    ROOT_DIR,
    download=False,
    checksum=False
)
# Out:
# CPU times: user 3min 5s, sys: 1.68 s, total: 3min 7s
# Wall time: 3min 6s

# %%
ds.bounds
# Out:
# BoundingBox(minx=-141.008104, maxx=-52.621493, miny=41.73535, maxy=74.773117, mint=0.0, maxt=9.223372036854776e+18)

# %%
bounds = BoundingBox(-79.69096183776855,-79.68220710754395,43.78839898848133,43.79482711775757,0,1)

# %%
ds.bounds.intersects(bounds)
# Out:
# True

# %%
# %%time
sample = ds[bounds]
# Out:
# CPU times: user 1min, sys: 597 ms, total: 1min
# Wall time: 1min

# %%
sample["masks"].shape
# Out:
# torch.Size([642, 875])

# %%
ds.plot(sample["masks"])

# %% [markdown]
# ## DataLoader example

# %%
sampler = RandomGeoSampler(
    roi=ds.bounds,
    size=256,
    length=48
)

# %%
dataloader = DataLoader(ds, sampler=sampler, batch_size=32)

# %%
for batch_idx, batch in enumerate(dataloader):
    print(batch["masks"].shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_867320/547832430.py in <module>
# ----> 1 for batch_idx, batch in enumerate(dataloader):
#       2     print(batch["masks"].shape)
#
# /opt/conda/envs/torchgeo1/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/envs/torchgeo1/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     558
#     559     def _next_data(self):
# --> 560         index = self._next_index()  # may raise StopIteration
#     561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#
# /opt/conda/envs/torchgeo1/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_index(self)
#     510
#     511     def _next_index(self):
# --> 512         return next(self._sampler_iter)  # may raise StopIteration
#     513
#     514     def _next_data(self):
#
# /opt/conda/envs/torchgeo1/lib/python3.8/site-packages/torch/utils/data/sampler.py in __iter__(self)
#     224     def __iter__(self) -> Iterator[List[int]]:
#     225         batch = []
# --> 226         for idx in self.sampler:
#     227             batch.append(idx)
#     228             if len(batch) == self.batch_size:
#
# ~/azurefiles/torchgeo/docs/notebooks/../../torchgeo/samplers/samplers.py in __iter__(self)
#      66         """
#      67         for _ in range(len(self)):
# ---> 68             minx = random.randint(int(self.roi.minx), int(self.roi.maxx) - self.size)
#      69             maxx = minx + self.size
#      70
#
# /opt/conda/envs/torchgeo1/lib/python3.8/random.py in randint(self, a, b)
#     246         """
#     247
# --> 248         return self.randrange(a, b+1)
#     249
#     250     def _randbelow_with_getrandbits(self, n):
#
# /opt/conda/envs/torchgeo1/lib/python3.8/random.py in randrange(self, start, stop, step, _int)
#     224             return istart + self._randbelow(width)
#     225         if step == 1:
# --> 226             raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     227
#     228         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (-141, -307, -166)
